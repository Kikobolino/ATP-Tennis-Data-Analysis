# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
# Defining path for data export
path = r'C:\Users\chris\OneDrive\Desktop\Data Analytics CF\06_Advanced Analytics\02_Prepared Data'

# %%
# Setting file location
files = glob.glob('C:/Users/chris/OneDrive/Desktop/Data Analytics CF/06_Advanced Analytics/01_Source Data/Tennis-Data.co.uk/*.xlsx')

# %%
# creating empty variable for list comprehension
frame = []

# %%
# Adding file names in list comprehension
for file in files:
    frame.append(pd.read_excel(file))
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\chris\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\chris\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\chris\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# Concatenating frames
df = pd.concat(frame, ignore_index = True)

# %%
df
# Out:
#        ATP     Location                  Tournament       Date         Series  \
# 0        1     Adelaide          AAPT Championships 2001-12-31  International
# 1        1     Adelaide          AAPT Championships 2001-12-31  International
# 2        1     Adelaide          AAPT Championships 2001-12-31  International
# 3        1     Adelaide          AAPT Championships 2001-12-31  International
# 4        1     Adelaide          AAPT Championships 2001-12-31  International
# ...    ...          ...                         ...        ...            ...
# 54169   36  Queens Club  Queen's Club Championships 2022-06-17         ATP500
# 54170   36  Queens Club  Queen's Club Championships 2022-06-17         ATP500
# 54171   36  Queens Club  Queen's Club Championships 2022-06-18         ATP500
# 54172   36  Queens Club  Queen's Club Championships 2022-06-18         ATP500
# 54173   36  Queens Club  Queen's Club Championships 2022-06-19         ATP500
#
# ...
